# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadAnang/PCVK/blob/main/pcvk1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# membuat list untuk menyimpan url dari beberapa image
urls = ["https://i.pinimg.com/564x/40/52/dc/4052dcc992e1babde2c2e703209339ba.jpg",
        "https://i.pinimg.com/564x/06/2d/82/062d820c601d35dd36dc41b86c88ba4e.jpg",
        "https://i.pinimg.com/564x/62/42/94/624294f32a2389bd7ae38d3557535e3a.jpg"]

#baca dan tampilkan image
#loop pada tiap url image, beberapa image dapat disimpan pada list

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=564x187>
# <PIL.Image.Image image mode=RGB size=564x352>
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image : tinggi x lebar = ", tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar =  501  x  282
# <PIL.Image.Image image mode=RGB size=282x501>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range(lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah
for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
#lamaa
for i in range(min(lebar, tinggi)):
    image_3[i, i] = [255, 255, 255]

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))


for i in range(min(lebar, tinggi)):
    image_3[i, lebar - i - 1] = [255, 255, 255]  # Warna putih

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar hasil
cv2_imshow(final_frame)



# BARUU BENERR
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Mendapatkan dimensi gambar
tinggi, lebar, _ = image.shape

# Membuat garis diagonal dari kiri atas ke kanan bawah
for i in range(min(lebar, tinggi)):
    image_3[int(i * tinggi / lebar), i] = [255, 255, 255]  # Warna putih


# Membuat garis diagonal dari kanan atas ke kiri bawah
for i in range(min(lebar, tinggi)):
    image_3[int(i * tinggi / lebar), lebar - i - 1] = [255, 255, 255]  # Warna putih

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar hasil
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
# Asumsikan 'image' sudah dibaca sebelumnya
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Panjang garis yang diinginkan (misalnya, setengah dari lebar gambar)
panjang_garis = lebar // 2

# Menentukan posisi awal dan akhir garis di tengah gambar
x_awal = (lebar - panjang_garis) // 2
x_akhir = x_awal + panjang_garis

# Membuat garis horizontal berwarna putih di tengah gambar
image_3[int(tinggi/2), x_awal:x_akhir] = [255, 255, 255]  # Warna putih

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar hasil
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
import random

# Asumsikan 'image' sudah dibaca sebelumnya
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Mendapatkan dimensi gambar
tinggi, lebar, _ = image.shape

# Tentukan ukuran kotak (misalnya 100x100 piksel)
ukuran_kotak = 100

# Tentukan posisi sembarang untuk kotak
x_awal = 20
y_awal = 50

# Buat kotak dengan warna putih di dalam gambar
image_3[y_awal:y_awal + ukuran_kotak, x_awal:x_awal + ukuran_kotak] = [255, 255, 255]  # Warna putih

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar hasil
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=564x501>

# %%
urls = ["https://tanda-air-ktp.vercel.app/ktp-example.jpg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x332>

# %%
# Asumsikan 'image' sudah dibaca sebelumnya
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Mendapatkan dimensi gambar
tinggi, lebar, _ = image.shape

# Tentukan ukuran kotak (misalnya 100x100 piksel)


# Tentukan posisi sembarang untuk kotak
x_awal = 150
y_awal = 85

# Buat kotak dengan warna putih di dalam gambar
image_3[y_awal:y_awal + 20, x_awal:x_awal + 150] = [0, 0, 255]  # Warna
image_3[125:125 + 20, x_awal:x_awal + 150] = [255, 255, 255]  # Warna


# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar hasil
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x332>

# %%
# !jupyter nbconvert --to html /content/pcvk1.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/pcvk1.ipynb to html
# [NbConvertApp] Writing 5004415 bytes to /content/pcvk1.html
